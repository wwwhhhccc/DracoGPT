# %%
import altair as alt
import pandas as pd
import json
import os

def transform_to_custom_spec(vega_lite_spec):
    vega_lite_json = json.loads(vega_lite_spec)
    
    if "spec" in vega_lite_json:
        if "encoding" in vega_lite_json["spec"]:
            spec_contents = vega_lite_json.pop("spec")
            vega_lite_json.update(spec_contents)
        else:
            raise ValueError('The "spec" field must contain an "encoding" field.')

    # Check and process "facet"
    if "facet" in vega_lite_json:
        if "row" in vega_lite_json["facet"] or "column" in vega_lite_json["facet"]:
            # Only append "row" part of "facet" if it exists, ignoring "column" for this instruction
            if "row" in vega_lite_json["facet"]:
                vega_lite_json["encoding"]["row"] = vega_lite_json["facet"]["row"]
            if "column" in vega_lite_json["facet"]:
                vega_lite_json["encoding"]["column"] = vega_lite_json["facet"]["column"]
            del vega_lite_json["facet"]
        else:
            raise ValueError('The "facet" field must contain either "row" or "column".')

    custom_spec = {"view": []}

    # Set up the view item
    view_item = {"coordinates": "cartesian", "mark": [], "scale": []}


    # Extract and handle the mark type
    mark = vega_lite_json.get("mark", {})
    mark_type = mark if isinstance(mark, str) else mark.get("type", None)

    if mark_type:
        mark_item = {"type": mark_type, "encoding": []}
        view_item["mark"].append(mark_item)
        
    

    # Handle encoding and scales
    encoding = vega_lite_json.get("encoding", {})
    encoded_fields = set()
    
    if len(encoding) > 3:
        raise ValueError(f"Encoding has length {len(encoding)}")

    for channel, details in encoding.items():
        if (details["field"] in ("q1", "q2") and details["type"] != "quantitative")\
            or (details["field"] == "n" and details["type"] not in ("ordinal", "nominal")):
            raise TypeError(f'Wrong variable type {details["type"]} for {details["field"]}')
            
        
        if channel not in ("x", "y", "color", "size", "row", "column", "shape"):
            raise ValueError(f"Encountered unrecognized channel: {channel}")
            
        if channel in ("row", "column"):
            f = details.get("field", "")
            if f == "":
                raise ValueError("can't find variable to facet on")
            view_item["facet"] = []
            view_item["facet"].append({"channel": channel, "field": f})
            encoded_fields.add(f)
            continue
            
            
        if mark_type:
            try:
                channel_item = {"channel": channel, "field": details["field"]}
            except Exception as e:
                raise ValueError(e)
            mark_item["encoding"].append(channel_item)
            encoded_fields.add(details["field"])

        # Determine scale type
        var_type = details["type"]
        scale_type = details.get("scale", {}).get("type", "")

        scale_item = {"channel": channel, "type": scale_type}
        if var_type == "quantitative":
            if scale_type not in ("", "linear"):
                raise ValueError(f"Invalid scale type for {var_type} type.")
            scale_item = {"channel": channel, "type": "linear"}
            zero = str(details.get("scale", {}).get("zero", True)).lower()
            # modified
            if zero == "true":
                scale_item["zero"] = zero
        elif var_type in ("ordinal", "nominal"):
            if "zero" in details.get("scale", {}):
                raise ValueError(f"'zero' field is not valid for {var_type} type.")
            if scale_type not in ("", "categorical", "ordinal"):
                raise ValueError(f"Invalid scale type for {var_type} type.")

            if channel == "color":
                scale_item = {"channel": channel, "type": "categorical"}
            elif channel in ("x", "y", "shape"):
                scale_item = {"channel": channel, "type": "ordinal"}
            

        view_item["scale"].append(scale_item)

    # Check if all required fields are present
    required_fields = {'q1', 'q2', 'n'}
    missing_fields = required_fields - encoded_fields
    if missing_fields:
        raise ValueError(f"Required field(s) not encoded: {', '.join(missing_fields)}")

    # Add the view item to custom spec
    custom_spec["view"].append(view_item)

    return json.dumps(custom_spec, indent=4)

# %%
def extract_json_from_file(file_path):
    with open(file_path, 'r') as file:
        text = file.read()

    # Find the position of the last 'content:'
    last_content_pos = text.rfind('content:')
    if last_content_pos == -1:
        print("No 'content:' found in the file.")
        return None

    # Find the position of the first '{' after the last 'content:'
    first_brace_pos = text.find('{', last_content_pos)

    if first_brace_pos == -1:
        print("No '{' found after the last 'content:'.")
        return None

    # Find the position of the last '}' in the file
    last_brace_pos = text.rfind('}')
    
    if last_brace_pos == -1:
        print("No closing '}' found in the file.")
        return None

    # Extract the JSON string
    json_str = text[first_brace_pos:last_brace_pos + 1].replace('\n', '').replace('"""','"')
    
    # Parse the JSON string into a Python object
    try:
        json_obj = json.loads(json_str)
        return json_obj
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
        return None

# %%
def extract_required_fields(num):
    file_path = f"./common_partial_spec/kim2018/{num}.txt"

    # Check if the file exists
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"File not found: {file_path}")

    # Read and parse the JSON file
    with open(file_path, 'r') as file:
        content = json.load(file)

    # Required fields
    required_fields = ['task', 'number_rows', 'field']

    # Dictionary to store the required fields and their values
    fields_values = {}

    # Check if each required field is present and add to the dictionary
    for field in required_fields:
        if field not in content:
            raise ValueError(f"Required field '{field}' not found in the file {file_path}")
        fields_values[field] = content[field]

    # Return the dictionary of required fields and the entire content
    return fields_values, content

# %%
def compare_dicts(d1, d2):
    if d1.keys() != d2.keys():
        return False

    for key in d1:
        if isinstance(d1[key], list) and isinstance(d2[key], list):
            # If lists, sort or convert to sets before comparing
            if all(isinstance(item, dict) for item in d1[key]):
                # If list of dicts, recursively compare
                if not all(any(compare_dicts(item1, item2) for item2 in d2[key]) for item1 in d1[key]):
                    return False
            elif set(d1[key]) != set(d2[key]):
                return False
        elif isinstance(d1[key], dict) and isinstance(d2[key], dict):
            # If dicts, recursively compare
            if not compare_dicts(d1[key], d2[key]):
                return False
        elif d1[key] != d2[key]:
            return False

    return True

# %%
def compare_json_lists(list1, list2):
    """
    Compare two lists of JSON objects, returning the common elements.
    """
    common = []
    for item1 in list1:
        for item2 in list2:
            if item1 == item2:
                common.append(item1)
                break
    return common
    

def extract_common_chart_properties(chart1, chart2):
    """
    Extract common chart properties from two chart specifications.
    """
    if chart1['task'] != chart2['task'] or chart1['number_rows'] != chart2['number_rows']:
        raise ValueError("Task and number of rows must be the same in both charts")

    if 'field' in chart1 and 'field' in chart2:
        if chart1['field'] != chart2['field']:
            raise ValueError("Fields must be the same in both charts")

    common_properties = {
        'task': chart1['task'],
        'number_rows': chart1['number_rows'],
        'field': chart1['field']
    }

    if chart1['view'][0]['coordinates'] == chart2['view'][0]['coordinates']:
        common_properties['view'] = {'coordinates': chart1['view'][0]['coordinates']}
    
    if chart1['view'][0]['mark'][0]['type'] == chart2['view'][0]['mark'][0]['type']:
        common_properties['view']['mark'] = [{'type': chart1['view'][0]['mark'][0]['type']}]

    
    encoding_common = compare_json_lists(chart1['view'][0]['mark'][0].get('encoding', []), chart2['view'][0]['mark'][0].get('encoding', []))
    if encoding_common:
        common_properties['view']['mark'][0] = common_properties['view']['mark'][0] | {"encoding":encoding_common}

    scale_common = compare_json_lists(chart1['view'][0].get('scale', []), chart2['view'][0].get('scale', []))
    if scale_common:
        common_properties['view']['scale'] = scale_common

    if 'facet' in chart1['view'][0] and 'facet' in chart2['view'][0] and chart1['view'][0]['facet'] == chart2['view'][0]['facet']:
        common_properties['view']['facet'] = chart1['view'][0]['facet']

    return common_properties

def are_json_objects_equivalent(json_str1, json_str2):
    try:
        # Parse the JSON strings into Python dictionaries
        dict1 = json.loads(json_str1)
        dict2 = json.loads(json_str2)

        # Compare the dictionaries
        return dict1 == dict2
    except json.JSONDecodeError:
        # If either string is not valid JSON, return False
        return False

# %%
'''
This block extracts the vl code from gpt response and writes to another folder
'''

def write_altair_to_dict_results(source_dir, destination_dir):
    bad_response = 0
    successful_writes = 0
    # Create the destination directory if it doesn't exist
    os.makedirs(destination_dir, exist_ok=True)

    # Iterate through each file in the source directory
    for filename in os.listdir(source_dir):
        # Check if the file is a .txt file
        if filename.endswith('.txt'):
            #first get data properties
#             print(filename)
            underscore_index = filename.find('_')

            # Check if underscore was found
            if underscore_index == -1:
                raise ValueError("no _ found")

            # Extract the substring to the left of the underscore
            left_substring = filename[:underscore_index]

            summary_stats, common_partial_spec = extract_required_fields(left_substring)
            common_partial_spec["view"] = [common_partial_spec["view"]]





            source_file = os.path.join(source_dir, filename)
            destination_file = os.path.join(destination_dir, filename)
            try:
                code_string = "chart = " + extract_json_from_file(source_file)["chart"]
            except Exception as e:
                bad_response += 1
                print(filename, f"Error: {e}")
                with open(destination_file, 'w') as file:
                    file.write("error")
                continue
            
            local_scope = {}
            try:
                data = '''df = pd.DataFrame({'q1': [10],'q2': [20],'n': ['A']})\n'''
                code_string = data + code_string
                code_string = code_string.replace("alt.Chart()", "alt.Chart(df)")
                
                exec(code_string, globals(), local_scope)
                
                chart = local_scope['chart']

                # Print the chart's JSON
                content_str = chart.to_json(indent=2)
                
                
                custom_chart_spec = transform_to_custom_spec(content_str)
                custom_chart_spec = {**summary_stats, **(json.loads(custom_chart_spec))}

                common = extract_common_chart_properties(custom_chart_spec, common_partial_spec)
                common["view"] = [common["view"]]


                if not compare_dicts(common, common_partial_spec):
                    bad_response += 1
                    print(filename,"partial spec violated")
                    with open(destination_file, 'w') as file:
                        file.write("error")
                else:
                    successful_writes += 1
                    with open(destination_file, 'w') as file:
                        
                        file.write(str(custom_chart_spec).replace("'", '"'))
            except Exception as e:
                bad_response += 1
                print(filename, f"Error: {e}")
                with open(destination_file, 'w') as file:
                    file.write("error")
    print("Valid Rate:", successful_writes/(successful_writes+bad_response))
    print("Bad response count:", bad_response)
    print("Successful writes:", successful_writes)
    print("TXT files processed successfully.")

# %%
source_dir = './gpt_responses/kim2018_responses/altair_gpt-4-0125-preview_0'
destination_dir = './to_dict_gpt_responses/kim2018_responses/altair_gpt-4-0125-preview_0'
write_altair_to_dict_results(source_dir, destination_dir)
# Out:
# 939_gpt-4-0125-preview_0.txt Error: Wrong variable type nominal for q2
# 964_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 214_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 348_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 834_gpt-4-0125-preview_0.txt Error: Wrong variable type nominal for q2
# 582_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 935_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 877_gpt-4-0125-preview_0.txt Error: 'zero' field is not valid for nominal type.
# 163_gpt-4-0125-preview_0.txt partial spec violated
# 826_gpt-4-0125-preview_0.txt Error: Wrong variable type nominal for q2
# 411_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 132_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 415_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 422_gpt-4-0125-preview_0.txt Error: Wrong variable type nominal for q2
# 16_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 1075_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 621_gpt-4-0125-preview_0.txt Error: Wrong variable type nominal for q2
# 977_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 1124_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 382_gpt-4-0125-preview_0.txt Error: 'field'
# 1128_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 20_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 948_gpt-4-0125-preview_0.txt partial spec violated
# 490_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 364_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 771_gpt-4-0125-preview_0.txt partial spec violated
# 922_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 360_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 1000_gpt-4-0125-preview_0.txt Error: Wrong variable type nominal for q2
# 633_gpt-4-0125-preview_0.txt Error: Wrong variable type nominal for q2
# 853_gpt-4-0125-preview_0.txt Error: Wrong variable type nominal for q2
# 1080_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 587_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 930_gpt-4-0125-preview_0.txt Error: Wrong variable type nominal for q2
# 917_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 168_gpt-4-0125-preview_0.txt partial spec violated
# 182_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 1018_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 1014_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 160_gpt-4-0125-preview_0.txt partial spec violated
# 281_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 711_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 1094_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 275_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 958_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 343_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 177_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 786_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 782_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 1145_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 996_gpt-4-0125-preview_0.txt partial spec violated
# 1141_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 824_gpt-4-0125-preview_0.txt Error: Wrong variable type nominal for q2
# 428_gpt-4-0125-preview_0.txt Error: Wrong variable type nominal for q2
# 138_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# Valid Rate: 0.9522569444444444
# Bad response count: 55
# Successful writes: 1097
# TXT files processed successfully.

# %%
source_dir = './gpt_responses/kim2018_responses/altair_gpt-4-0613_0'
destination_dir = './to_dict_gpt_responses/kim2018_responses/altair_gpt-4-0613_0'
write_altair_to_dict_results(source_dir, destination_dir)
# Out:
# 660_gpt-4-0613_0.txt Error: Encoding has length 4
# 582_gpt-4-0613_0.txt partial spec violated
# 938_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 820_gpt-4-0613_0.txt partial spec violated
# 624_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 845_gpt-4-0613_0.txt partial spec violated
# 132_gpt-4-0613_0.txt partial spec violated
# 737_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 1031_gpt-4-0613_0.txt Error: Encoding has length 4
# 468_gpt-4-0613_0.txt Error: Wrong variable type nominal for q2
# 1054_gpt-4-0613_0.txt partial spec violated
# 589_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 1075_gpt-4-0613_0.txt partial spec violated
# 294_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 449_gpt-4-0613_0.txt partial spec violated
# 896_gpt-4-0613_0.txt Error: Encoding has length 4
# 977_gpt-4-0613_0.txt Error: Encoding has length 4
# 728_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 473_gpt-4-0613_0.txt Error: Encoding has length 4
# 248_gpt-4-0613_0.txt partial spec violated
# 194_gpt-4-0613_0.txt Error: Encoding has length 4
# 1014_gpt-4-0613_0.txt partial spec violated
# 40_gpt-4-0613_0.txt partial spec violated
# 811_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 830_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 937_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 87_gpt-4-0613_0.txt Error: Wrong variable type nominal for q2
# 61_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 1035_gpt-4-0613_0.txt Error: Encoding has length 4
# 756_gpt-4-0613_0.txt partial spec violated
# 1050_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 952_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 218_gpt-4-0613_0.txt partial spec violated
# 1118_gpt-4-0613_0.txt Error: Encoding has length 4
# 1021_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 841_gpt-4-0613_0.txt partial spec violated
# 1083_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 664_gpt-4-0613_0.txt Error: Encoding has length 4
# 860_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 886_gpt-4-0613_0.txt Error: 'categorical' is an invalid value for `type`. Valid values are one of ['linear', 'log', 'pow', 'sqrt', 'symlog', 'identity', 'sequential', 'time', 'utc', 'quantile', 'quantize', 'threshold', 'bin-ordinal', 'ordinal', 'point', 'band'].
# 981_gpt-4-0613_0.txt Error: Encoding has length 4
# 31_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 207_gpt-4-0613_0.txt Error: `AxisConfig` has no parameter named 'scale'
#
# Existing parameter names are:
# aria               gridDash           labelLimit        tickColor        titleBaseline
# bandPosition       gridDashOffset     labelLineHeight   tickCount        titleColor
# description        gridOpacity        labelOffset       tickDash         titleFont
# disable            gridWidth          labelOpacity      tickDashOffset   titleFontSize
# domain             labelAlign         labelOverlap      tickExtra        titleFontStyle
# domainCap          labelAngle         labelPadding      tickMinStep      titleFontWeight
# domainColor        labelBaseline      labelSeparation   tickOffset       titleLimit
# domainDash         labelBound         labels            tickOpacity      titleLineHeight
# domainDashOffset   labelColor         maxExtent         tickRound        titleOpacity
# domainOpacity      labelExpr          minExtent         tickSize         titlePadding
# domainWidth        labelFlush         offset            tickWidth        titleX
# format             labelFlushOffset   orient            ticks            titleY
# formatType         labelFont          position          title            translate
# grid               labelFontSize      style             titleAlign       values
# gridCap            labelFontStyle     tickBand          titleAnchor      zindex
# gridColor          labelFontWeight    tickCap           titleAngle
#
# See the help for `AxisConfig` to read the full description of these parameters
# 324_gpt-4-0613_0.txt Error: Encoding has length 4
# 521_gpt-4-0613_0.txt partial spec violated
# 426_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 821_gpt-4-0613_0.txt partial spec violated
# 907_gpt-4-0613_0.txt Error: Encoding has length 4
# 800_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 1102_gpt-4-0613_0.txt Error: 'q1' is an invalid value for `title`. Valid values are of type 'null'.
# 604_gpt-4-0613_0.txt Error: Encoding has length 4
# 138_gpt-4-0613_0.txt partial spec violated
# 500_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 281_gpt-4-0613_0.txt partial spec violated
# 687_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 360_gpt-4-0613_0.txt Error: Encoding has length 4
# 1086_gpt-4-0613_0.txt Error: name 'zero' is not defined
# 717_gpt-4-0613_0.txt partial spec violated
# 413_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 1128_gpt-4-0613_0.txt partial spec violated
# 20_gpt-4-0613_0.txt partial spec violated
# 149_gpt-4-0613_0.txt Error: Encoding has length 4
# 177_gpt-4-0613_0.txt partial spec violated
# 490_gpt-4-0613_0.txt partial spec violated
# 654_gpt-4-0613_0.txt Error: name 'zero' is not defined
# 550_gpt-4-0613_0.txt Error: name 'zero' is not defined
# 888_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 736_gpt-4-0613_0.txt Error: Encoding has length 4
# 1051_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 256_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 929_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 917_gpt-4-0613_0.txt partial spec violated
# 277_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 1096_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 600_gpt-4-0613_0.txt Error: Encoding has length 4
# 1106_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 206_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 55_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 958_gpt-4-0613_0.txt partial spec violated
# 30_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 364_gpt-4-0613_0.txt Error: Encoding has length 4
# 1064_gpt-4-0613_0.txt Error: Encoding has length 4
# 587_gpt-4-0613_0.txt partial spec violated
# 644_gpt-4-0613_0.txt partial spec violated
# 345_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 1045_gpt-4-0613_0.txt Error: Wrong variable type nominal for q2
# 979_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 922_gpt-4-0613_0.txt partial spec violated
# 1127_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 621_gpt-4-0613_0.txt partial spec violated
# 1020_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 726_gpt-4-0613_0.txt Error: Encoding has length 4
# 648_gpt-4-0613_0.txt partial spec violated
# 1077_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 894_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 1056_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 1033_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 59_gpt-4-0613_0.txt partial spec violated
# 498_gpt-4-0613_0.txt Error: Encoding has length 4
# 1145_gpt-4-0613_0.txt Error: Encoding has length 4
# 1042_gpt-4-0613_0.txt Error: 'q1' is an invalid value for `title`. Valid values are of type 'null'.
# 16_gpt-4-0613_0.txt partial spec violated
# 879_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 105_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 803_gpt-4-0613_0.txt Error: Encoding has length 4
# 858_gpt-4-0613_0.txt Error: Encoding has length 4
# 961_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 662_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 461_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 68_gpt-4-0613_0.txt Error: Encoding has length 4
# 56_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 400_gpt-4-0613_0.txt partial spec violated
# 539_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 182_gpt-4-0613_0.txt partial spec violated
# 584_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 884_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 862_gpt-4-0613_0.txt Error: Encoding has length 4
# 944_gpt-4-0613_0.txt partial spec violated
# 1078_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 299_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 1141_gpt-4-0613_0.txt Error: Encoding has length 4
# 323_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 1124_gpt-4-0613_0.txt partial spec violated
# 826_gpt-4-0613_0.txt Error: Wrong variable type nominal for q2
# 950_gpt-4-0613_0.txt Error: Encoding has length 4
# 935_gpt-4-0613_0.txt Error: Encoding has length 4
# 1130_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 134_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 532_gpt-4-0613_0.txt partial spec violated
# 115_gpt-4-0613_0.txt Error: Wrong variable type nominal for q2
# 1016_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 848_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 19_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 971_gpt-4-0613_0.txt Error: `AxisConfig` has no parameter named 'scale'
#
# Existing parameter names are:
# aria               gridDash           labelLimit        tickColor        titleBaseline
# bandPosition       gridDashOffset     labelLineHeight   tickCount        titleColor
# description        gridOpacity        labelOffset       tickDash         titleFont
# disable            gridWidth          labelOpacity      tickDashOffset   titleFontSize
# domain             labelAlign         labelOverlap      tickExtra        titleFontStyle
# domainCap          labelAngle         labelPadding      tickMinStep      titleFontWeight
# domainColor        labelBaseline      labelSeparation   tickOffset       titleLimit
# domainDash         labelBound         labels            tickOpacity      titleLineHeight
# domainDashOffset   labelColor         maxExtent         tickRound        titleOpacity
# domainOpacity      labelExpr          minExtent         tickSize         titlePadding
# domainWidth        labelFlush         offset            tickWidth        titleX
# format             labelFlushOffset   orient            ticks            titleY
# formatType         labelFont          position          title            translate
# grid               labelFontSize      style             titleAlign       values
# gridCap            labelFontStyle     tickBand          titleAnchor      zindex
# gridColor          labelFontWeight    tickCap           titleAngle
#
# See the help for `AxisConfig` to read the full description of these parameters
# 590_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 1095_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 292_gpt-4-0613_0.txt Error: Encoding has length 4
# 734_gpt-4-0613_0.txt Error: `AxisConfig` has no parameter named 'scale'
#
# Existing parameter names are:
# aria               gridDash           labelLimit        tickColor        titleBaseline
# bandPosition       gridDashOffset     labelLineHeight   tickCount        titleColor
# description        gridOpacity        labelOffset       tickDash         titleFont
# disable            gridWidth          labelOpacity      tickDashOffset   titleFontSize
# domain             labelAlign         labelOverlap      tickExtra        titleFontStyle
# domainCap          labelAngle         labelPadding      tickMinStep      titleFontWeight
# domainColor        labelBaseline      labelSeparation   tickOffset       titleLimit
# domainDash         labelBound         labels            tickOpacity      titleLineHeight
# domainDashOffset   labelColor         maxExtent         tickRound        titleOpacity
# domainOpacity      labelExpr          minExtent         tickSize         titlePadding
# domainWidth        labelFlush         offset            tickWidth        titleX
# format             labelFlushOffset   orient            ticks            titleY
# formatType         labelFont          position          title            translate
# grid               labelFontSize      style             titleAlign       values
# gridCap            labelFontStyle     tickBand          titleAnchor      zindex
# gridColor          labelFontWeight    tickCap           titleAngle
#
# See the help for `AxisConfig` to read the full description of these parameters
# 537_gpt-4-0613_0.txt partial spec violated
# 1032_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 235_gpt-4-0613_0.txt Error: Encoding has length 4
# 992_gpt-4-0613_0.txt partial spec violated
# 1048_gpt-4-0613_0.txt partial spec violated
# 376_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 348_gpt-4-0613_0.txt partial spec violated
# 214_gpt-4-0613_0.txt partial spec violated
# 411_gpt-4-0613_0.txt partial spec violated
# 110_gpt-4-0613_0.txt Error: 'n' is an invalid value for `title`. Valid values are of type 'null'.
# 782_gpt-4-0613_0.txt partial spec violated
# 36_gpt-4-0613_0.txt partial spec violated
# 986_gpt-4-0613_0.txt Error: name 'zero' is not defined
# 960_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 53_gpt-4-0613_0.txt partial spec violated
# 1007_gpt-4-0613_0.txt Error: `AxisConfig` has no parameter named 'x'
#
# Existing parameter names are:
# aria               gridDash           labelLimit        tickColor        titleBaseline
# bandPosition       gridDashOffset     labelLineHeight   tickCount        titleColor
# description        gridOpacity        labelOffset       tickDash         titleFont
# disable            gridWidth          labelOpacity      tickDashOffset   titleFontSize
# domain             labelAlign         labelOverlap      tickExtra        titleFontStyle
# domainCap          labelAngle         labelPadding      tickMinStep      titleFontWeight
# domainColor        labelBaseline      labelSeparation   tickOffset       titleLimit
# domainDash         labelBound         labels            tickOpacity      titleLineHeight
# domainDashOffset   labelColor         maxExtent         tickRound        titleOpacity
# domainOpacity      labelExpr          minExtent         tickSize         titlePadding
# domainWidth        labelFlush         offset            tickWidth        titleX
# format             labelFlushOffset   orient            ticks            titleY
# formatType         labelFont          position          title            translate
# grid               labelFontSize      style             titleAlign       values
# gridCap            labelFontStyle     tickBand          titleAnchor      zindex
# gridColor          labelFontWeight    tickCap           titleAngle
#
# See the help for `AxisConfig` to read the full description of these parameters
# 1100_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 1018_gpt-4-0613_0.txt partial spec violated
# 924_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 29_gpt-4-0613_0.txt Error: Encoding has length 4
# 198_gpt-4-0613_0.txt Error: Encoding has length 4
# 140_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 343_gpt-4-0613_0.txt partial spec violated
# 546_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 920_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 799_gpt-4-0613_0.txt Error: Encoding has length 4
# 445_gpt-4-0613_0.txt partial spec violated
# 964_gpt-4-0613_0.txt partial spec violated
# 1080_gpt-4-0613_0.txt partial spec violated
# 786_gpt-4-0613_0.txt partial spec violated
# 1094_gpt-4-0613_0.txt Error: Encoding has length 4
# 695_gpt-4-0613_0.txt Error: name 'zero' is not defined
# 275_gpt-4-0613_0.txt partial spec violated
# 891_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 877_gpt-4-0613_0.txt partial spec violated
# 18_gpt-4-0613_0.txt Error: 'Chart' object has no attribute 'scale'
# 711_gpt-4-0613_0.txt partial spec violated
# 415_gpt-4-0613_0.txt Error: Encoding has length 4
# 231_gpt-4-0613_0.txt Error: Encoding has length 4
# 730_gpt-4-0613_0.txt Error: Encoding has length 4
# Valid Rate: 0.8454861111111112
# Bad response count: 178
# Successful writes: 974
# TXT files processed successfully.

# %%
source_dir = './gpt_responses/kim2018_responses/altair_gpt-3.5-turbo-0125_0'
destination_dir = './to_dict_gpt_responses/kim2018_responses/altair_gpt-3.5-turbo-0125_0'
write_altair_to_dict_results(source_dir, destination_dir)
# Out:
# 683_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 119_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 1131_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 1106_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 177_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 702_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 735_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 140_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 1087_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 630_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# Error decoding JSON: Expecting value: line 1 column 33 (char 32)
# 57_gpt-3.5-turbo-0125_0.txt Error: 'NoneType' object is not subscriptable
# 607_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 60_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 39_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 1003_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 786_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 669_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# Error decoding JSON: Expecting value: line 1 column 33 (char 32)
# 1034_gpt-3.5-turbo-0125_0.txt Error: 'NoneType' object is not subscriptable
# 221_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 454_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 951_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 889_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 966_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 463_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 216_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 908_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 278_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 397_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 508_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 292_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 489_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 863_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 566_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 313_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 324_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 551_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 854_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 1083_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 144_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# Error decoding JSON: Expecting value: line 1 column 33 (char 32)
# 731_gpt-3.5-turbo-0125_0.txt Error: 'NoneType' object is not subscriptable
# 706_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 173_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 1102_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 1135_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 768_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 687_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 1030_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 782_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 1007_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 199_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 64_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 603_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# Error decoding JSON: Expecting value: line 1 column 33 (char 32)
# 53_gpt-3.5-turbo-0125_0.txt Error: 'NoneType' object is not subscriptable
# 1069_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 634_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 393_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 409_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 212_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 467_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 962_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 588_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 955_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 450_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 225_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# Error decoding JSON: Expecting value: line 1 column 33 (char 32)
# 850_gpt-3.5-turbo-0125_0.txt Error: 'NoneType' object is not subscriptable
# 555_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 320_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 317_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 562_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 867_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 988_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 296_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 379_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 809_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 661_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 656_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# Error decoding JSON: Expecting value: line 1 column 33 (char 32)
# 31_gpt-3.5-turbo-0125_0.txt Error: 'NoneType' object is not subscriptable
# 68_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 195_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 1052_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 638_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 1065_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 148_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 82_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 753_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 126_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 111_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 764_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 1139_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 559_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 984_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 481_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 342_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 832_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 537_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 500_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 805_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 375_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 405_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 900_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 270_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 247_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 937_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 432_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 881_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 584_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 229_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 959_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 1061_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 1056_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 191_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 35_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 652_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 1038_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 665_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 760_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 115_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 122_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 757_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 86_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 739_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 371_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 801_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 504_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 533_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 836_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 346_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 485_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 980_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 858_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 328_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 458_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 580_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 885_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 436_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 933_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 243_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 274_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
# 904_gpt-3.5-turbo-0125_0.txt Error: can only concatenate str (not "dict") to str
#