# %%
import json
import os
import altair as alt

def transform_to_custom_spec(vega_lite_spec):
    vega_lite_json = json.loads(vega_lite_spec)
    
    if "spec" in vega_lite_json:
        if "encoding" in vega_lite_json["spec"]:
            spec_contents = vega_lite_json.pop("spec")
            vega_lite_json.update(spec_contents)
        else:
            raise ValueError('The "spec" field must contain an "encoding" field.')

    # Check and process "facet"
    if "facet" in vega_lite_json:
        if "row" in vega_lite_json["facet"] or "column" in vega_lite_json["facet"]:
            if "row" in vega_lite_json["facet"]:
                vega_lite_json["encoding"]["row"] = vega_lite_json["facet"]["row"]
            if "column" in vega_lite_json["facet"]:
                vega_lite_json["encoding"]["column"] = vega_lite_json["facet"]["column"]
            del vega_lite_json["facet"]
        else:
            raise ValueError('The "facet" field must contain either "row" or "column".')

    custom_spec = {"view": []}

    # Set up the view item
    view_item = {"coordinates": "cartesian", "mark": [], "scale": []}


    # Extract and handle the mark type
    mark = vega_lite_json.get("mark", {})
    mark_type = mark if isinstance(mark, str) else mark.get("type", None)

    if mark_type:
        mark_item = {"type": mark_type, "encoding": []}
        view_item["mark"].append(mark_item)
        
    

    # Handle encoding and scales
    encoding = vega_lite_json.get("encoding", {})
    encoded_fields = set()
    
    if len(encoding) > 3:
        raise ValueError(f"Encoding has length {len(encoding)}")

    for channel, details in encoding.items():
        if (details["field"] in ("q1", "q2") and details["type"] != "quantitative")\
            or (details["field"] == "n" and details["type"] not in ("ordinal", "nominal")):
            raise TypeError(f'Wrong variable type {details["type"]} for {details["field"]}')
            
        
        if channel not in ("x", "y", "color", "size", "row", "column", "shape"):
            raise ValueError(f"Encountered unrecognized channel: {channel}")
            
        if channel in ("row", "column"):
            f = details.get("field", "")
            if f == "":
                raise ValueError("can't find variable to facet on")
            view_item["facet"] = []
            view_item["facet"].append({"channel": channel, "field": f})
            encoded_fields.add(f)
            continue
            
            
        if mark_type:
            try:
                channel_item = {"channel": channel, "field": details["field"]}
            except Exception as e:
                raise ValueError(e)
            mark_item["encoding"].append(channel_item)
            encoded_fields.add(details["field"])

        # Determine scale type
        var_type = details["type"]
        scale_type = details.get("scale", {}).get("type", "")

        scale_item = {"channel": channel, "type": scale_type}
        if var_type == "quantitative":
            if scale_type not in ("", "linear"):
                raise ValueError(f"Invalid scale type for {var_type} type.")
            scale_item = {"channel": channel, "type": "linear"}
            zero = str(details.get("scale", {}).get("zero", True)).lower()
            # modified
            if zero == "true":
                scale_item["zero"] = zero
        elif var_type in ("ordinal", "nominal"):
            if "zero" in details.get("scale", {}):
                raise ValueError(f"'zero' field is not valid for {var_type} type.")
            if scale_type not in ("", "categorical", "ordinal"):
                raise ValueError(f"Invalid scale type for {var_type} type.")

            if channel == "color":
                scale_item = {"channel": channel, "type": "categorical"}
            elif channel in ("x", "y", "shape"):
                scale_item = {"channel": channel, "type": "ordinal"}
            

        view_item["scale"].append(scale_item)

    # Check if all required fields are present
    required_fields = {'q1', 'q2', 'n'}
    missing_fields = required_fields - encoded_fields
    if missing_fields:
        raise ValueError(f"Required field(s) not encoded: {', '.join(missing_fields)}")

    # Add the view item to custom spec
    custom_spec["view"].append(view_item)

    return json.dumps(custom_spec, indent=4)

# # Example Vega-Lite spec
# vega_lite_spec = '''
# {
#     "description" : { "id" : 0 },
#     "$schema": "https://vega.github.io/schema/vega-lite/v5.json",
#     "mark": "point",
#     "encoding": {
#       "color": {"field": "q1", "type": "quantitative"},
#       "y": {"field": "q2", "type": "quantitative"},
#       "x": {"field": "n", "type": "nominal"}
#     }
# }
# '''

# # Transform and print the custom chart spec
# try:
#     custom_chart_spec = transform_to_custom_spec(vega_lite_spec)
#     print(custom_chart_spec)
# except ValueError as e:
#     print(f"Error: {e}")

# %%
def extract_json_from_file(file_path):
    with open(file_path, 'r') as file:
        text = file.read()

    # Find the position of the last 'content:'
    last_content_pos = text.rfind('content:')
    if last_content_pos == -1:
        print("No 'content:' found in the file.")
        return None

    # Find the position of the first '{' after the last 'content:'
    first_brace_pos = text.find('{', last_content_pos)

    if first_brace_pos == -1:
        print("No '{' found after the last 'content:'.")
        return None

    # Find the position of the last '}' in the file
    last_brace_pos = text.rfind('}')
    
    if last_brace_pos == -1:
        print("No closing '}' found in the file.")
        return None

    # Extract the JSON string
    json_str = text[first_brace_pos:last_brace_pos + 1]
    # Parse the JSON string into a Python object
    try:
        json_obj = json.loads(json_str)
        return json_obj
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
        return None

# %%
def extract_required_fields(num):
    file_path = f"./common_partial_spec/kim2018/{num}.txt"

    # Check if the file exists
    if not os.path.exists(file_path):
        raise FileNotFoundError(f"File not found: {file_path}")

    # Read and parse the JSON file
    with open(file_path, 'r') as file:
        content = json.load(file)

    # Required fields
    required_fields = ['task', 'number_rows', 'field']

    # Dictionary to store the required fields and their values
    fields_values = {}

    # Check if each required field is present and add to the dictionary
    for field in required_fields:
        if field not in content:
            raise ValueError(f"Required field '{field}' not found in the file {file_path}")
        fields_values[field] = content[field]

    # Return the dictionary of required fields and the entire content
    return fields_values, content

# %%
def compare_dicts(d1, d2):
    if d1.keys() != d2.keys():
        return False

    for key in d1:
        if isinstance(d1[key], list) and isinstance(d2[key], list):
            # If lists, sort or convert to sets before comparing
            if all(isinstance(item, dict) for item in d1[key]):
                # If list of dicts, recursively compare
                if not all(any(compare_dicts(item1, item2) for item2 in d2[key]) for item1 in d1[key]):
                    return False
            elif set(d1[key]) != set(d2[key]):
                return False
        elif isinstance(d1[key], dict) and isinstance(d2[key], dict):
            # If dicts, recursively compare
            if not compare_dicts(d1[key], d2[key]):
                return False
        elif d1[key] != d2[key]:
            return False

    return True

# %%
def compare_json_lists(list1, list2):
    """
    Compare two lists of JSON objects, returning the common elements.
    """
    common = []
    for item1 in list1:
        for item2 in list2:
            if item1 == item2:
                common.append(item1)
                break
    return common
    

def extract_common_chart_properties(chart1, chart2):
    """
    Extract common chart properties from two chart specifications.
    """
    if chart1['task'] != chart2['task'] or chart1['number_rows'] != chart2['number_rows']:
        raise ValueError("Task and number of rows must be the same in both charts")

    if 'field' in chart1 and 'field' in chart2:
        if chart1['field'] != chart2['field']:
            raise ValueError("Fields must be the same in both charts")

    common_properties = {
        'task': chart1['task'],
        'number_rows': chart1['number_rows'],
        'field': chart1['field']
    }

    if chart1['view'][0]['coordinates'] == chart2['view'][0]['coordinates']:
        common_properties['view'] = {'coordinates': chart1['view'][0]['coordinates']}
    
    if chart1['view'][0]['mark'][0]['type'] == chart2['view'][0]['mark'][0]['type']:
        common_properties['view']['mark'] = [{'type': chart1['view'][0]['mark'][0]['type']}]

    
    encoding_common = compare_json_lists(chart1['view'][0]['mark'][0].get('encoding', []), chart2['view'][0]['mark'][0].get('encoding', []))
    if encoding_common:
        common_properties['view']['mark'][0] = common_properties['view']['mark'][0] | {"encoding":encoding_common}

    scale_common = compare_json_lists(chart1['view'][0].get('scale', []), chart2['view'][0].get('scale', []))
    if scale_common:
        common_properties['view']['scale'] = scale_common

    if 'facet' in chart1['view'][0] and 'facet' in chart2['view'][0] and chart1['view'][0]['facet'] == chart2['view'][0]['facet']:
        common_properties['view']['facet'] = chart1['view'][0]['facet']

    return common_properties

def are_json_objects_equivalent(json_str1, json_str2):
    try:
        # Parse the JSON strings into Python dictionaries
        dict1 = json.loads(json_str1)
        dict2 = json.loads(json_str2)

        # Compare the dictionaries
        return dict1 == dict2
    except json.JSONDecodeError:
        # If either string is not valid JSON, return False
        print("JSONDecodeError")
        return False

# %%
'''
This block extracts the vl code from gpt response and writes to another folder
'''
def write_vl_to_dict_results(source_dir, destination_dir):
    bad_response = 0
    successful_writes = 0
    # Create the destination directory if it doesn't exist
    os.makedirs(destination_dir, exist_ok=True)
    # Iterate through each file in the source directory
    for filename in os.listdir(source_dir):
        # Check if the file is a .txt file
        if filename.endswith('.txt'):
            #first get data properties

            underscore_index = filename.find('_')

            # Check if underscore was found
            if underscore_index == -1:
                raise ValueError("no _ found")

            # Extract the substring to the left of the underscore
            left_substring = filename[:underscore_index]

            summary_stats, common_partial_spec = extract_required_fields(left_substring)
            common_partial_spec["view"] = [common_partial_spec["view"]]





            source_file = os.path.join(source_dir, filename)
            destination_file = os.path.join(destination_dir, filename)

            content = extract_json_from_file(source_file)["chart"]


            content_str = str(content).replace("'", '"')
            content_str = content_str.replace("True", '"true"').replace("False", '"false"').replace("None", '"None"')


            try:
                custom_chart_spec = transform_to_custom_spec(content_str)
                custom_chart_spec = {**summary_stats, **(json.loads(custom_chart_spec))}

                common = extract_common_chart_properties(custom_chart_spec, common_partial_spec)
                common["view"] = [common["view"]]

                # inject fake data to check if valid vl spec
                spec_with_data = content
                spec_with_data['data'] = {"values": {"q1": 1, "q2": 2, "n": "N"}}
                alt.Chart.from_dict(spec_with_data)

                if not compare_dicts(common, common_partial_spec):
                    bad_response += 1
                    print(filename, "partial spec violated")
                    with open(destination_file, 'w') as file:
                        file.write("error")
                else:
                    with open(destination_file, 'w') as file:
                        file.write(str(custom_chart_spec).replace("'", '"'))
                    successful_writes += 1
                
                
            except Exception as e:
                bad_response += 1
                print(filename, f"Error: {str(e)[:30]}")
                with open(destination_file, 'w') as file:
                    file.write("error")
                    
    print("Valid Rate:", successful_writes/(successful_writes+bad_response))
    print("Bad response count:", bad_response)
    print("Successful writes:", successful_writes)
    print("TXT files processed successfully.")

# %%
source_dir = './gpt_responses/kim2018_responses/gpt-4-0125-preview_0'
destination_dir = './to_dict_gpt_responses/kim2018_responses/gpt-4-0125-preview_0'
write_vl_to_dict_results(source_dir, destination_dir)
# Out:
# 964_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 214_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 553_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 348_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 59_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 803_gpt-4-0125-preview_0.txt partial spec violated
# 218_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 582_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 935_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 235_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 877_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 231_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 29_gpt-4-0125-preview_0.txt partial spec violated
# 990_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 411_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 105_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 132_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 415_gpt-4-0125-preview_0.txt partial spec violated
# 16_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 1075_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 498_gpt-4-0125-preview_0.txt partial spec violated
# 845_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 445_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 977_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 717_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 1124_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 841_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 137_gpt-4-0125-preview_0.txt Error: Wrong variable type linear for
# 1128_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 20_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 490_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 364_gpt-4-0125-preview_0.txt partial spec violated
# 449_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 922_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 360_gpt-4-0125-preview_0.txt partial spec violated
# 604_gpt-4-0125-preview_0.txt partial spec violated
# 736_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 680_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 600_gpt-4-0125-preview_0.txt partial spec violated
# 1080_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 587_gpt-4-0125-preview_0.txt partial spec violated
# 907_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 58_gpt-4-0125-preview_0.txt Error: Wrong variable type linear for
# 917_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 182_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 799_gpt-4-0125-preview_0.txt partial spec violated
# 1018_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 1014_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 281_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 711_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 1094_gpt-4-0125-preview_0.txt partial spec violated
# 726_gpt-4-0125-preview_0.txt partial spec violated
# 664_gpt-4-0125-preview_0.txt partial spec violated
# 275_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 981_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 532_gpt-4-0125-preview_0.txt partial spec violated
# 149_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 194_gpt-4-0125-preview_0.txt partial spec violated
# 660_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 958_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 343_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 198_gpt-4-0125-preview_0.txt partial spec violated
# 1031_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 730_gpt-4-0125-preview_0.txt partial spec violated
# 1035_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 862_gpt-4-0125-preview_0.txt partial spec violated
# 537_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 68_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 858_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 292_gpt-4-0125-preview_0.txt partial spec violated
# 177_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 786_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 53_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 782_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 644_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 1145_gpt-4-0125-preview_0.txt partial spec violated
# 1118_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 1141_gpt-4-0125-preview_0.txt partial spec violated
# 521_gpt-4-0125-preview_0.txt Error: Encoding has length 4
# 992_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 1048_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 138_gpt-4-0125-preview_0.txt Error: Required field(s) not encoded:
# 648_gpt-4-0125-preview_0.txt partial spec violated
# Valid Rate: 0.9279513888888888
# Bad response count: 83
# Successful writes: 1069
# TXT files processed successfully.

# %%
source_dir = './gpt_responses/kim2018_responses/gpt-4-0613_0'
destination_dir = './to_dict_gpt_responses/kim2018_responses/gpt-4-0613_0'
write_vl_to_dict_results(source_dir, destination_dir)
# Out:
# 660_gpt-4-0613_0.txt Error: Encoding has length 4
# 582_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 564_gpt-4-0613_0.txt Error: Encoding has length 4
# 97_gpt-4-0613_0.txt Error: Required field(s) not encoded:
# 427_gpt-4-0613_0.txt partial spec violated
# 699_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 845_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 208_gpt-4-0613_0.txt Error: Required field(s) not encoded:
# 132_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 1031_gpt-4-0613_0.txt Error: Encoding has length 4
# 1054_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 1075_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 449_gpt-4-0613_0.txt partial spec violated
# 477_gpt-4-0613_0.txt partial spec violated
# 977_gpt-4-0613_0.txt Error: Encoding has length 4
# 310_gpt-4-0613_0.txt Error: Required field(s) not encoded:
# 749_gpt-4-0613_0.txt Error: Required field(s) not encoded:
# 194_gpt-4-0613_0.txt Error: Encoding has length 4
# 1014_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 1035_gpt-4-0613_0.txt Error: Encoding has length 4
# 756_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 1088_gpt-4-0613_0.txt Error: Encoding has length 4
# 218_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 841_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 467_gpt-4-0613_0.txt Error: 'none' is not of type 'array'
#
# 664_gpt-4-0613_0.txt Error: Encoding has length 4
# 886_gpt-4-0613_0.txt Error: 'categorical' is not one of ['
# 981_gpt-4-0613_0.txt Error: Encoding has length 4
# 738_gpt-4-0613_0.txt Error: Required field(s) not encoded:
# 300_gpt-4-0613_0.txt Error: Required field(s) not encoded:
# 722_gpt-4-0613_0.txt Error: Invalid scale type for ordinal
# 604_gpt-4-0613_0.txt Error: Encoding has length 4
# 138_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 281_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 360_gpt-4-0613_0.txt Error: Encoding has length 4
# 717_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 1128_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 990_gpt-4-0613_0.txt Error: Required field(s) not encoded:
# 20_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 392_gpt-4-0613_0.txt Error: Required field(s) not encoded:
# 149_gpt-4-0613_0.txt Error: Encoding has length 4
# 177_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 490_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 736_gpt-4-0613_0.txt Error: Encoding has length 4
# 953_gpt-4-0613_0.txt Error: Encoding has length 4
# 152_gpt-4-0613_0.txt Error: Encoding has length 4
# 732_gpt-4-0613_0.txt Error: Invalid scale type for ordinal
# 334_gpt-4-0613_0.txt Error: Invalid scale type for ordinal
# 917_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 614_gpt-4-0613_0.txt Error: 'categorical' is not one of ['
# 790_gpt-4-0613_0.txt Error: Invalid scale type for ordinal
# 600_gpt-4-0613_0.txt Error: Encoding has length 4
# 238_gpt-4-0613_0.txt Error: Invalid scale type for ordinal
# 958_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 364_gpt-4-0613_0.txt Error: Encoding has length 4
# 1064_gpt-4-0613_0.txt Error: Encoding has length 4
# 587_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 181_gpt-4-0613_0.txt Error: Invalid scale type for ordinal
# 382_gpt-4-0613_0.txt Error: Encoding has length 4
# 285_gpt-4-0613_0.txt Error: Invalid scale type for ordinal
# 683_gpt-4-0613_0.txt partial spec violated
# 466_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 644_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 922_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 726_gpt-4-0613_0.txt Error: Encoding has length 4
# 648_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 771_gpt-4-0613_0.txt Error: 'none' is not of type 'array'
#
# 632_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 59_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 498_gpt-4-0613_0.txt Error: Encoding has length 4
# 1145_gpt-4-0613_0.txt Error: Encoding has length 4
# 440_gpt-4-0613_0.txt Error: Required field(s) not encoded:
# 16_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 626_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 201_gpt-4-0613_0.txt Error: Invalid scale type for ordinal
# 607_gpt-4-0613_0.txt Error: Invalid scale type for ordinal
# 803_gpt-4-0613_0.txt Error: Encoding has length 4
# 858_gpt-4-0613_0.txt Error: Encoding has length 4
# 68_gpt-4-0613_0.txt Error: Encoding has length 4
# 182_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 381_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 862_gpt-4-0613_0.txt Error: Encoding has length 4
# 944_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 1141_gpt-4-0613_0.txt Error: Encoding has length 4
# 1124_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 950_gpt-4-0613_0.txt Error: Encoding has length 4
# 935_gpt-4-0613_0.txt Error: Encoding has length 4
# 532_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 292_gpt-4-0613_0.txt Error: Encoding has length 4
# 58_gpt-4-0613_0.txt Error: Invalid scale type for ordinal
# 537_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 235_gpt-4-0613_0.txt Error: Encoding has length 4
# 154_gpt-4-0613_0.txt Error: Required field(s) not encoded:
# 992_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 1048_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 348_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 214_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 411_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 782_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 53_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 405_gpt-4-0613_0.txt Error: Required field(s) not encoded:
# 619_gpt-4-0613_0.txt partial spec violated
# 1018_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 29_gpt-4-0613_0.txt Error: Encoding has length 4
# 198_gpt-4-0613_0.txt Error: Encoding has length 4
# 343_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 420_gpt-4-0613_0.txt partial spec violated
# 799_gpt-4-0613_0.txt Error: Encoding has length 4
# 379_gpt-4-0613_0.txt partial spec violated
# 445_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 32_gpt-4-0613_0.txt Error: Required field(s) not encoded:
# 964_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 1080_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 786_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 901_gpt-4-0613_0.txt Error: Required field(s) not encoded:
# 171_gpt-4-0613_0.txt Error: Required field(s) not encoded:
# 1094_gpt-4-0613_0.txt Error: Encoding has length 4
# 275_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 877_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 812_gpt-4-0613_0.txt Error: Required field(s) not encoded:
# 43_gpt-4-0613_0.txt Error: 'categorical' is not one of ['
# 711_gpt-4-0613_0.txt Error: 'zero' field is not valid for
# 114_gpt-4-0613_0.txt Error: Required field(s) not encoded:
# 415_gpt-4-0613_0.txt Error: Encoding has length 4
# 231_gpt-4-0613_0.txt Error: Encoding has length 4
# 434_gpt-4-0613_0.txt Error: 'none' is not of type 'array'
#
# 730_gpt-4-0613_0.txt Error: Encoding has length 4
# 652_gpt-4-0613_0.txt Error: Invalid scale type for ordinal
# 353_gpt-4-0613_0.txt Error: Invalid scale type for ordinal
# 188_gpt-4-0613_0.txt Error: Encoding has length 4
# Valid Rate: 0.8871527777777778
# Bad response count: 130
# Successful writes: 1022
# TXT files processed successfully.

# %%
source_dir = './gpt_responses/kim2018_responses/gpt-3.5-turbo-0125_0'
destination_dir = './to_dict_gpt_responses/kim2018_responses/gpt-3.5-turbo-0125_0'
write_vl_to_dict_results(source_dir, destination_dir)
# Out:
# 683_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 119_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1106_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 702_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 735_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 140_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1087_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 630_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 607_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 39_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1003_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 669_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 221_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 454_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 951_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 966_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 463_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 216_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 908_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 278_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 397_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 508_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 489_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 863_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 566_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 313_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 324_gpt-3.5-turbo-0125_0.txt partial spec violated
# 551_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 854_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1083_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 144_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 731_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 706_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 173_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1102_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1135_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 768_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 687_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 782_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1007_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 199_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 64_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1069_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 634_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 393_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 212_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 467_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 955_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 225_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 850_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 555_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 320_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 317_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 562_gpt-3.5-turbo-0125_0.txt partial spec violated
# 867_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 988_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 296_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 379_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 809_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 661_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 656_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 31_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 195_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1065_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 753_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 126_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 111_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 764_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1139_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 559_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 984_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 342_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 832_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 537_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 500_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 405_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 900_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 247_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 937_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 432_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 584_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 229_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1061_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1056_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 191_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 35_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 652_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1038_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 665_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 760_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 115_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 122_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 757_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 86_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 801_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 346_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 485_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 328_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 580_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 885_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 436_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 933_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 274_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 904_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 401_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 385_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 428_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 471_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 974_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 204_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 943_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 446_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 336_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 543_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 574_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 871_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 301_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 358_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 280_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 727_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1095_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 165_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 98_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 710_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 749_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1114_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 691_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1123_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 794_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1026_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1011_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 615_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1048_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 72_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 622_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 45_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 442_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 947_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 237_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 200_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 970_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 475_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 929_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 259_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 381_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 284_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 529_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 305_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 875_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 570_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 547_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 332_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 695_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1110_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1149_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 714_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 161_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1091_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 723_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 41_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 626_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 76_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 611_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1022_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 790_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 18_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 288_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 817_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 512_gpt-3.5-turbo-0125_0.txt partial spec violated
# 367_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 350_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 525_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 820_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 879_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 996_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 479_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 596_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 893_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 420_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 925_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 3_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 417_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 262_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1077_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 187_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1040_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 673_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 14_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 103_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 776_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 699_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 741_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 134_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 90_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1145_gpt-3.5-turbo-0125_0.txt partial spec violated
# 992_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 578_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 824_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 521_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 354_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 516_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 813_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 266_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 7_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 413_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 916_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 389_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 921_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 424_gpt-3.5-turbo-0125_0.txt partial spec violated
# 251_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 897_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 592_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 208_gpt-3.5-turbo-0125_0.txt Error: Required field(s) not encoded:
# 978_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 10_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 27_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 640_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1044_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 619_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1073_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 49_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1099_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1141_gpt-3.5-turbo-0125_0.txt partial spec violated
# 94_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 169_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 130_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1118_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 772_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 107_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 40_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 627_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 610_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1014_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1023_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 791_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 19_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1126_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 694_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1111_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1148_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 160_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1090_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 157_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 722_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 285_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 528_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 304_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 571_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 874_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 843_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 546_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 333_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 946_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 443_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 236_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 201_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 474_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 971_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 928_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 258_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 380_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 795_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1027_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1010_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 614_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 73_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 623_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 44_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 153_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1094_gpt-3.5-turbo-0125_0.txt partial spec violated
# 164_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 99_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1115_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 690_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1122_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 337_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 542_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 847_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 870_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 575_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 829_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 281_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 384_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 429_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 975_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 470_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 205_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 232_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 447_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 942_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1098_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 95_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 168_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 131_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1119_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 744_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 773_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 106_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 799_gpt-3.5-turbo-0125_0.txt Error: Wrong variable type quantitati
# 676_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 26_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 641_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1045_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 618_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1072_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 267_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 6_gpt-3.5-turbo-0125_0.txt partial spec violated
# 917_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 388_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 425_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 920_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 250_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 593_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 896_gpt-3.5-turbo-0125_0.txt partial spec violated
# 209_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 496_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 520_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 825_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 355_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 362_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 812_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 517_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 102_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 777_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 698_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 740_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 135_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 719_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 91_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 186_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1041_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 22_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 15_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 478_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 892_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 597_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 254_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 924_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 421_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 416_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 913_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 263_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 289_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 513_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 816_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 366_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 351_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 821_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 524_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 997_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 492_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 851_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 321_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 316_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 866_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 989_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 297_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 378_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 808_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 392_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 408_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 213_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 963_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 466_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 451_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 954_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 224_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1006_gpt-3.5-turbo-0125_0.txt Error: Required field(s) not encoded:
# 65_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 602_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 52_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 635_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1082_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 145_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 730_gpt-3.5-turbo-0125_0.txt partial spec violated
# 707_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1103_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1134_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 769_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 686_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 509_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 293_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 488_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 567_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 862_gpt-3.5-turbo-0125_0.txt partial spec violated
# 325_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 855_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 550_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 220_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 950_gpt-3.5-turbo-0125_0.txt partial spec violated
# 455_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 888_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 462_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 967_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 217_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 909_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 631_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 56_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 606_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 61_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 38_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1002_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 668_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 682_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 118_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1107_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 176_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 703_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 734_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 141_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1086_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 459_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 884_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 581_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 932_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 437_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 242_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 275_gpt-3.5-turbo-0125_0.txt Error: 'zero' field is not valid for
# 400_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 905_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 370_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 800_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 837_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 532_gpt-3.5-turbo-0125_0.txt Error: 'zero' field is not valid for
# 981_gpt-3.5-turbo-0125_0.txt partial spec violated
# 484_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 859_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 329_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 761_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 114_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 123_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 756_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 87_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 738_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1060_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1057_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 190_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 653_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1039_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 664_gpt-3.5-turbo-0125_0.txt Error: Wrong variable type quantitati
# 901_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 404_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 271_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 246_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 433_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 936_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 585_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 880_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 228_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 558_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 480_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 985_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 343_gpt-3.5-turbo-0125_0.txt Error: 'zero' field is not valid for
# 833_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 804_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 501_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 374_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 83_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 752_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 110_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 765_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1138_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 30_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 69_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1053_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1064_gpt-3.5-turbo-0125_0.txt partial spec violated
# 238_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 948_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 890_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 256_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 423_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 926_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 911_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 261_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 814_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 353_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 526_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 823_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 995_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 548_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 100_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 775_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1128_gpt-3.5-turbo-0125_0.txt Error: 'zero' field is not valid for
# 742_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 137_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 93_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1146_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 159_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 629_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1074_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 79_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 184_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 647_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 670_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 265_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 410_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 915_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 4_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 922_gpt-3.5-turbo-0125_0.txt Error: 'zero' field is not valid for
# 427_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 894_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 591_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 849_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 339_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 991_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 494_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 827_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 522_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 357_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 810_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 728_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1142_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 97_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 746_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 771_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 104_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 13_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1029_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 674_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 24_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 643_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1047_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 180_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 335_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 540_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 498_gpt-3.5-turbo-0125_0.txt partial spec violated
# 872_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 519_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 283_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 8_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 919_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 269_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 386_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 898_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 977_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 207_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 940_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 797_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1025_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1012_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 616_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 71_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 621_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 46_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 724_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 151_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1096_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 166_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 713_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1117_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 692_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 108_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1120_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 287_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 368_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 818_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 306_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 876_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 573_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 999_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 544_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 841_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 441_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 944_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 203_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 973_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 382_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 418_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 42_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1078_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 625_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 75_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 612_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1016_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1021_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 793_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1124_gpt-3.5-turbo-0125_0.txt Error: 'zero' field is not valid for
# 779_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 696_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1113_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 717_gpt-3.5-turbo-0125_0.txt Error: 'zero' field is not valid for
# 162_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1092_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 155_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 720_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 709_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 81_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 750_gpt-3.5-turbo-0125_0.txt Error: 'zero' field is not valid for
# 125_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 767_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 688_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 662_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 655_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1008_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 196_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1051_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1066_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 406_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 903_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 273_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 244_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 431_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 468_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 882_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 587_gpt-3.5-turbo-0125_0.txt Error: 'zero' field is not valid for
# 868_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 318_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 987_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 482_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 341_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 299_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 503_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 806_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 376_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 763_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 116_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 121_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1109_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 754_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 85_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1150_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1088_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1062_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 58_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 608_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 192_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 36_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 651_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 789_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 886_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 969_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 435_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 930_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 240_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 277_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 907_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 402_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 398_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 372_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 507_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 530_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 835_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 345_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 486_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 983_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 569_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 633_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1059_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 63_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1000_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 785_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1037_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 680_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1132_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 758_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1105_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 174_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 89_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 701_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 736_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 143_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1084_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 291_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 839_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 860_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 565_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 310_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 327_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 552_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 222_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 457_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 952_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 439_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 394_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1033_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 781_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1004_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 50_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 637_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 147_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 732_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 705_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 170_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 129_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1101_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1136_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 684_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 556_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 323_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 314_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 864_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 390_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 938_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 248_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 211_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 464_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 961_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 956_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 453_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 226_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 373_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 506_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 834_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 531_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 982_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 568_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 218_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 968_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 931_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 434_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 241_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 403_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 906_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 399_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1063_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 59_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1054_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 609_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 37_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 650_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 788_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 667_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 762_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 117_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1108_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 755_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1151_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 84_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 179_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1089_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 869_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 319_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 483_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 986_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 340_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 535_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 830_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 298_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 807_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 902_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 407_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 245_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 430_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 935_gpt-3.5-turbo-0125_0.txt partial spec violated
# 469_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 586_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 883_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 654_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1050_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1067_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 708_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 80_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 124_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 766_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 689_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 391_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 939_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 210_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 960_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 465_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 452_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 957_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 227_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 557_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 852_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 322_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 315_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 865_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 560_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 539_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 294_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 146_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 733_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 704_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 171_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 128_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1100_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1137_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 685_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1032_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 780_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1005_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 658_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 66_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 601_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 51_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 636_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 223_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 456_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 461_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 214_gpt-3.5-turbo-0125_0.txt Error: 'zero' field is not valid for
# 438_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 395_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 290_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 564_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 311_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 326_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 856_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 553_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1133_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 759_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1104_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 175_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 88_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 700_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 737_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 142_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1085_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 632_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 55_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 605_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1058_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 62_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 784_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1036_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 12_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1028_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 675_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 25_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 642_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1046_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 181_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1071_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 96_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1143_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 132_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 747_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 770_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 105_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 848_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 338_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 495_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 523_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 826_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 361_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 811_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 514_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 264_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 914_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 411_gpt-3.5-turbo-0125_0.txt Error: 'zero' field is not valid for
# 5_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 426_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 253_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 590_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 628_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1075_gpt-3.5-turbo-0125_0.txt Error: 'zero' field is not valid for
# 78_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 185_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1042_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 646_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 671_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 16_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 101_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 774_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 743_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 92_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 158_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 510_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 365_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 352_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 822_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 994_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 549_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 239_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 949_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 891_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 594_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 257_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 927_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 422_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 910_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 260_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 778_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 697_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1112_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 716_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 163_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 154_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 721_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 43_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1079_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 624_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 74_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 613_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1017_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1020_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 792_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 440_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 202_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 477_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 598_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 383_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 419_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 286_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 369_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 819_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 307_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 572_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 877_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 840_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 330_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 725_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 150_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1097_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 167_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1116_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 693_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 109_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1121_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 796_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 679_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1024_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 1013_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 617_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 620_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 47_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 9_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 268_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 899_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 473_gpt-3.5-turbo-0125_0.txt Error: Wrong variable type quantitati
# 206_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 444_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 941_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 334_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 541_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 844_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 499_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 873_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 576_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 303_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# 518_gpt-3.5-turbo-0125_0.txt Error: Additional properties are not
# Valid Rate: 0.1909722222222222
# Bad response count: 932
# Successful writes: 220
# TXT files processed successfully.
